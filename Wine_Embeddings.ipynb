# %% [markdown]
# # Wine Embeddings and a Wine Recommender

# %%
import pandas as pd

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# ## Step 0. Подключение и обработка датасета от парсеров winestyle

# %%
# https://drive.google.com/file/d/1O9FbG4QbJhSDOiYNcitJQocRzjFPxlb4/view?usp=sharing
id = '1O9FbG4QbJhSDOiYNcitJQocRzjFPxlb4' 
downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('winestyle.csv')  
winestyle = pd.read_csv('winestyle.csv', index_col = 'id')

# %%
winestyle = winestyle.drop(columns=['url','image_url','strength'])

# %%
winestyle.head(40)
# Out:
#      id  ...                                        description
# 0   116  ...  Вино демонстрирует сложный аромат, сотканный и...
# 1   117  ...  В глубоком аромате вина ноты вишни, сливы и еж...
# 2   118  ...  Элегантный аромат вина раскрывается оттенками ...
# 3   119  ...  Вино демонстрирует элегантный, сдержанный аром...
# 4   120  ...  Вино демонстрирует глубокий аромат, сотканный ...
# 5   121  ...  Вино обладает освежающим ароматом с доминирующ...
# 6   122  ...  Вино демонстрирует сложный, богатый аромат, со...
# 7   123  ...  У вина гармоничный, изящный аромат с нотами яг...
# 8   124  ...  Вино чарует элегантным ароматом с доминирующим...
# 9   125  ...  Выразительный аромат вина изобилует оттенками ...
# 10  126  ...  Щедрый, богатый аромат вина раскрывается оттен...
# 11  127  ...  Вино демонстрирует богатый аромат с нотами виш...
# 12  128  ...  Вино демонстрирует элегантный, гармоничный аро...
# 13  129  ...  Вино интригует гармоничным ароматом с оттенкам...
# 14  130  ...  В элегантном аромате вина чувствуются оттенки ...
# 15  131  ...  Вино привлекает свежим, изящным ароматом с цит...
# 16  132  ...  Свежий, гармоничный аромат вина изобилует отте...
# 17  133  ...  Элегантный, свежий аромат вина раскрывается от...
# 18  134  ...  Вино демонстрирует освежающий аромат с цитрусо...
# 19  135  ...  Вино обладает свежим, элегантным ароматом с но...
# 20  136  ...  Элегантный аромат вина изобилует оттенками спе...
# 21  137  ...  Вино демонстрирует щедрый, гармоничный аромат,...
# 22  138  ...  Изящный аромат вина изобилует оттенками манго,...
# 23  139  ...  Гармоничный, изящный аромат вина раскрывается ...
# 24  140  ...  Вино привлекает свежим, изящным ароматом с отт...
# 25  141  ...  Вино демонстрирует элегантный аромат, сотканны...
# 26  142  ...  Элегантный аромат вина раскрывается оттенками ...
# 27  143  ...  Вино привлекает щедрым, гармоничным ароматом, ...
# 28  144  ...  Вино интригует свежим, элегантным ароматом, со...
# 29  145  ...  Вино демонстрирует выразительный аромат с доми...
# 30  146  ...  Вино привлекает гармоничным ароматом, сотканны...
# 31  147  ...  Выразительный аромат вина раскрывается оттенка...
# 32  148  ...  Элегантный аромат вина изобилует оттенками сли...
# 33  149  ...  Элегантный, гармоничный аромат вина раскрывает...
# 34  150  ...  В освежающем аромате вина чувствуются оттенки ...
# 35  151  ...  Свежий, элегантный аромат вина раскрывается от...
# 36  152  ...  Элегантный аромат вина наполнен тонами вишни, ...
# 37  153  ...  Вино демонстрирует насыщенный аромат с оттенка...
# 38  154  ...  Вино демонстрирует элегантный, гармоничный аро...
# 39  155  ...  Элегантный аромат вина изобилует оттенками зем...
#
# [40 rows x 15 columns]

# %%
winestyle.groupby(['type']).describe()
# Out:
#                         crop_year                          ... rating
#                             count         mean        std  ...    50%   75%  max
# type                                                       ...
# Вермут                        1.0  1757.000000        NaN  ...  4.500  5.00  5.0
# Винный напиток                0.0          NaN        NaN  ...  4.125  5.00  5.0
# Вино                      24225.0  2013.489618  14.877865  ...  4.000  4.50  5.0
# Десертное                    28.0  2003.750000  11.054160  ...  4.500  4.75  5.0
# Игристое                    487.0  2008.722793  27.985872  ...  4.050  4.55  5.0
# Игристый винный напиток       0.0          NaN        NaN  ...    NaN   NaN  NaN
# Кошерное                     34.0  2014.352941   4.898252  ...  3.250  4.00  4.5
# Крепленое                    34.0  1987.647059  27.614096  ...  4.125  4.65  5.0
# Плодовое                      0.0          NaN        NaN  ...  4.250  5.00  5.0
# Портвейн                    125.0  2001.232000  20.616755  ...  4.150  4.65  5.0
# Сухое                         3.0  2009.333333   2.081666  ...    NaN   NaN  NaN
# Херес                         8.0  1985.500000  17.848569  ...  4.000  4.65  5.0
# Шампанское                  398.0  2008.876884  61.714443  ...  4.400  5.00  5.0
#
# [13 rows x 32 columns]

# %%
winestyle['description'] = winestyle['aroma'] + ' ' + winestyle['taste'] + ' ' + winestyle['description']
winestyle = winestyle.drop(columns=['aroma','taste','food_pairing'])

# %%
winestyle.head()
# Out:
#                                                   name  ...                                        description
# id                                                      ...
# 116  "Chateau Les Jouberts" Cuvee Prestige, Blaye C...  ...  Вино демонстрирует сложный аромат, сотканный и...
# 117   Ramirez de la Piscina, Crianza, Rioja DOCa, 2015  ...  В глубоком аромате вина ноты вишни, сливы и еж...
# 118   Ramirez de la Piscina, Reserva, Rioja DOCa, 2014  ...  Элегантный аромат вина раскрывается оттенками ...
# 119            Rafael Cambra, Soplo, Valencia DO, 2014  ...  Вино демонстрирует элегантный, сдержанный аром...
# 120  Familia Bastida, "Drama" Red Blend, La Mancha ...  ...  Вино демонстрирует глубокий аромат, сотканный ...
#
# [5 rows x 14 columns]

# %% [markdown]
# ## Step 1. Нормализация

# %% [markdown]
# Загружаем переведенный descriptor_mapping_ru

# %%
#descriptor mapping rus
#https://drive.google.com/file/d/1jDN0iwcLrWFLEJbedy6DiZi2gz09MMyR/view?usp=sharing
#descriptor mapping rus norm
# https://drive.google.com/file/d/1-6TwyJIlJk5S-hYgiUAuqemXMeyPIZG6/view?usp=sharing
id = '1-6TwyJIlJk5S-hYgiUAuqemXMeyPIZG6' 
downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('descriptor_mapping_ru.csv')  
descriptor_mapping_ru = pd.read_csv('descriptor_mapping_ru.csv', sep=';')

# %% [markdown]
# Загружаем корпусы слов и знаков препинания, импортируем библиотеки

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer

# %% [markdown]
# Класс для нормализации строк: удаляет стоп-слова и пунктуацию, использует стеммер для удаления лишних суффиксов и окончаний

# %%
class Normalizer:

    def __init__(self, lang='russian'):
        self.stemmer = SnowballStemmer(lang)
        self.stop = stopwords.words(lang)
    
    def normalise_description(self, description, to_string=False):
        description = str(description)
        description = description.replace('-', ' ')
        tokens = word_tokenize(description.lower())
        normalised_tokens = [self.stemmer.stem(w) for w in tokens if w.isalpha() and w not in self.stop]
        return normalised_tokens if not to_string else ' '.join(normalised_tokens)

# %%
norm = Normalizer()
norm.normalise_description('соя')
#norm.normalise_description(test_description, to_string=True)
# Out:
# ['со']

# %% [markdown]
# Создаём нормализованный descriptor mapping ru

# %%
def create_norm_descriptor_mapping():
    norm = Normalizer()
    for column in descriptor_mapping_ru.columns:
      for i in range(len(descriptor_mapping_ru)):
        # if descriptor_mapping_ru[column][i].find('-') != -1:
        #   print(descriptor_mapping_ru[column][i])
        descriptor_mapping_ru[column][i] = norm.normalise_description(descriptor_mapping_ru[column][i], to_string=True)
    descriptor_mapping_ru.to_csv('descriptor_mapping_ru_norm.csv')

# %%
# create_norm_descriptor_mapping()
descriptor_mapping_ru.head()
# Out:
#    Unnamed: 0  level_1        level_2    level_3 raw_descriptor
# 0           0  кислотн  высок кислотн    кислотн        кислотн
# 1           1  кислотн  высок кислотн  агрессивн      агрессивн
# 2           2  кислотн  высок кислотн   напорист       напорист
# 3           3  кислотн  высок кислотн        ярк            ярк
# 4           4  кислотн  высок кислотн     яркост         яркост

# %% [markdown]
# ## Step 2. Создание и подгрузка корпуса слов

# %% [markdown]
# Создаем единый файл со всеми описаниями (корпус)

# %%
def create_corpus(descriptions):
    norm = Normalizer()
    with open('corpus_winestyle.txt', 'w') as corpus_file:
        for d in descriptions:
            print(norm.normalise_description(d, to_string=True), file=corpus_file)

# %%
# corpus_winestyle, winestyle_filtered подгружаются с диска
pre_created = True

# %% [markdown]
# На основе этого корпуса создаем модели биграмм и триграмм, встречающихся хотя бы 10 раз, сохраняем модели в соответствующие файлы

# %%
from gensim.test.utils import datapath
from gensim.models.word2vec import Text8Corpus
from gensim.models.phrases import Phrases, Phraser

# %%
# %%capture
if (not pre_created):
    create_corpus(winestyle['description'])
    sentences = Text8Corpus('corpus_winestyle.txt')
    phrases = Phrases(sentences, min_count=10, threshold=1)
else:
    id_corpus_winestyle = '1U61JUm1zbgJnRS8U3cKbNt9KDkOpsLWr'
    # https://drive.google.com/file/d/1U61JUm1zbgJnRS8U3cKbNt9KDkOpsLWr/view?usp=sharing
    downloaded = drive.CreateFile({'id':id_corpus_winestyle}) 
    downloaded.GetContentFile('corpus_winestyle.txt')  
    sentences = Text8Corpus('corpus_winestyle.txt')

# %% [markdown]
# ## Step 3. Word2Vec

# %%
from gensim.models import Word2Vec
file_object=open("corpus_winestyle.txt","r")
data = Text8Corpus('corpus_winestyle.txt')
word2vec = Word2Vec(data, size=300)

# wine_word2vec_model = Word2Vec(sentences, size=300, min_count=1, iter=15)

# wine_word2vec_model.save('wine_word2vec_model.bin')

# %%
from difflib import get_close_matches

descriptors = descriptor_mapping_ru['raw_descriptor']

def count_matches(word, string, method='count'):
    if method == 'fuzzy':
        return len(get_close_matches(word, string, cutoff=0.8))
    elif method == 'count':
        return ' '.join(string).count(word)

def map_descriptors(normalised_description, level='raw_descriptor'):
    descriptorised_description = {}
    for i, word in enumerate(descriptors):
        count = count_matches(word, normalised_description)
        if count:
            descriptorised_description[descriptor_mapping_ru[level][i]] = count
    return descriptorised_description

# %%
description = winestyle['description'][116]

norm = Normalizer()
normalised_description = norm.normalise_description(description)
print(description)
print(normalised_description)

map_descriptors(normalised_description, level='level_3')
# Out:
# Вино демонстрирует сложный аромат, сотканный из нот черной смородины, ванили, кокоса, розмарина и гвоздики. Вино обладает щедрым, ярким вкусом с оттенками черешни, кофе и трюфелей, с мягкими танинами и долгим, приятным послевкусием. "Chateau Les Jouberts" Cuvee Prestige, Blaye Cotes de Bordeaux AOC, 2014 — красное сухое вино, созданное из винограда сорта Мерло, который произрастает на виноградниках в аппелласьоне Блай Кот де Бордо на глинисто-гравийных почвах. Сбор урожая проводится лишь по достижении ягод оптимальной спелости, винификация сусла проходит при строго контролируемой температуре в резервуарах из нержавеющей стали. Выдерживается вино 12 месяцев в бочках из французского дуба. Потенциал вина составляет 5 лет.
# ['вин', 'демонстрир', 'сложн', 'аромат', 'сотка', 'нот', 'черн', 'смородин', 'ван', 'кокос', 'розмарин', 'гвоздик', 'вин', 'облада', 'щедр', 'ярк', 'вкус', 'оттенк', 'черешн', 'коф', 'трюфел', 'мягк', 'танин', 'долг', 'приятн', 'послевкус', 'chatea', 'les', 'jouberts', 'cuv', 'prestig', 'bla', 'cotes', 'de', 'bordeaux', 'aoc', 'красн', 'сух', 'вин', 'созда', 'виноград', 'сорт', 'мерл', 'котор', 'произраста', 'виноградник', 'аппелласьон', 'бла', 'кот', 'де', 'борд', 'глинист', 'гравийн', 'почв', 'сбор', 'урож', 'провод', 'лиш', 'достижен', 'ягод', 'оптимальн', 'спелост', 'винификац', 'сусл', 'проход', 'строг', 'контролируем', 'температур', 'резервуар', 'нержавеющ', 'стал', 'выдержива', 'вин', 'месяц', 'бочк', 'французск', 'дуб', 'потенциа', 'вин', 'составля', 'лет']
# {'ван': 1,
#  'виноград': 1,
#  'гвоздик': 1,
#  'глин': 1,
#  'грав': 1,
#  'дер': 1,
#  'дик': 1,
#  'долг': 1,
#  'дуб': 1,
#  'кокос': 1,
#  'коф': 1,
#  'лад': 1,
#  'мягк': 1,
#  'мягк танин': 1,
#  'пот': 1,
#  'ржав': 1,
#  'роз': 1,
#  'розмарин': 1,
#  'сложн': 1,
#  'смородин': 1,
#  'сот': 1,
#  'спел': 1,
#  'средн': 1,
#  'стал': 1,
#  'суглинок': 1,
#  'сух': 1,
#  'танин': 1,
#  'тим': 1,
#  'трюфел': 1,
#  'французск дуб': 1,
#  'черн смородин': 1,
#  'щедр': 1,
#  'ягод': 1,
#  'ярк': 1}

# %%
descriptor_mapping_ru['level_3'].value_counts()
# Out:
# яблок         11
# дуб           11
# коф            8
# вишн           7
# стал           7
#               ..
# зел фасол      1
# помадк         1
# ветчин         1
# опилк          1
# лемонграсс     1
# Name: level_3, Length: 564, dtype: int64

# %% [markdown]
# Записываем в датасет нормализованные описания, которые также отфильтрованы через дескрипторы

# %%
def return_descriptor_from_mapping(desc):
    normalised_description = norm.normalise_description(desc)
    description_to_return = ''
    map = map_descriptors(normalised_description, level='level_3')
    for key in map.keys():
        words = ''
        for i in range(map.get(key)):
            words += key + ' '
        words = words.rstrip(' ')
        description_to_return += words + ' '
    description_to_return = description_to_return.rstrip(' ')
    return description_to_return
        
if not pre_created:
    for id in winestyle.index:
        winestyle.loc[id, 'description'] = return_descriptor_from_mapping(winestyle['description'][id])
    winestyle.to_csv('winestyle_filtered.csv')
    winestyle_filtered = pd.read_csv('winestyle_filtered.csv', index_col = 'id')
else:
    # https://drive.google.com/file/d/1wTNzilsOszlgRRiSXnOlvI_IWWtisxqs/view?usp=sharing
    id = '1wTNzilsOszlgRRiSXnOlvI_IWWtisxqs' 
    downloaded = drive.CreateFile({'id':id}) 
    downloaded.GetContentFile('winestyle_filtered.csv')  
    winestyle_filtered = pd.read_csv('winestyle_filtered.csv', index_col = 'id')

# %%
winestyle_filtered['description'][116]
# Out:
# 'ярк дик пот сот сложн щедр мягк спел стал глин грав трюфел суглинок долг средн роз черн смородин смородин ягод виноград гвоздик сух ржав танин мягк танин розмарин тим кокос французск дуб дуб ван дер коф лад'

# %%
winestyle_filtered['description'][116]
# Out:
# 'ярк дик пот сот сложн щедр мягк спел стал глин грав трюфел суглинок долг средн роз черн смородин смородин ягод виноград гвоздик сух ржав танин мягк танин розмарин тим кокос французск дуб дуб ван дер коф лад'

# %% [markdown]
# ## Step 4. Vectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from operator import itemgetter
vectorizer = TfidfVectorizer()
X = vectorizer.fit(winestyle_filtered['description'].values.astype('U'))

dict_of_tfidf_weightings = dict(zip(X.get_feature_names(), X.idf_))

wine_review_vectors = []
notfound = []
for i, d in enumerate(winestyle_filtered['description'].values.astype('U')):
    descriptor_count = 0
    weighted_review_terms = []
    terms = d.split(' ')
    for term in terms:
        if term in dict_of_tfidf_weightings.keys():
            tfidf_weighting = dict_of_tfidf_weightings[term]
            try:
                word_vector = word2vec.wv.get_vector(term).reshape(1, 300)
            except:
                notfound.append(term)
            weighted_word_vector = tfidf_weighting * word_vector
            weighted_review_terms.append(weighted_word_vector)
            descriptor_count += 1
        else:
            continue
    try:
        review_vector = sum(weighted_review_terms)/len(weighted_review_terms)
    except:
        review_vector = []
    vector_and_count = [terms, review_vector, descriptor_count, i]
    wine_review_vectors.append(vector_and_count)

winestyle_upgrade = winestyle.copy()
winestyle_upgrade['normalized_descriptors'] = list(map(itemgetter(0), wine_review_vectors))
winestyle_upgrade['review_vector'] = list(map(itemgetter(1), wine_review_vectors))
winestyle_upgrade['descriptor_count'] = list(map(itemgetter(2), wine_review_vectors))

winestyle.reset_index(inplace=True)
winestyle_upgrade.head()
# Out:
#                                                   name  ... descriptor_count
# id                                                      ...
# 116  "Chateau Les Jouberts" Cuvee Prestige, Blaye C...  ...               37
# 117   Ramirez de la Piscina, Crianza, Rioja DOCa, 2015  ...               33
# 118   Ramirez de la Piscina, Reserva, Rioja DOCa, 2014  ...               45
# 119            Rafael Cambra, Soplo, Valencia DO, 2014  ...               26
# 120  Familia Bastida, "Drama" Red Blend, La Mancha ...  ...               41
#
# [5 rows x 17 columns]

# %%
import numpy as np

wine_review_vectors = [w for w in wine_review_vectors if w[2] > 5]

X_train = np.array([w[1].flatten() for w in wine_review_vectors])
np.random.shuffle(X_train)

# %%
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
link = linkage(X_train[:100], method='ward', metric='euclidean')

# %%
from matplotlib import pyplot as plt

fig = plt.figure(figsize=(10, 10))
dendrogram(link, orientation='right', color_threshold=25)
plt.show()

# %% [markdown]
# ## Step 5. KNN

# %%
X = np.array([w[1].flatten() for w in wine_review_vectors])
y = np.array([w[3] for w in wine_review_vectors])

# %%
from sklearn.preprocessing import StandardScaler

X = StandardScaler().fit_transform(X)

# %%
from sklearn.neighbors import NearestNeighbors
# from sklearn.metrics.pairwise import cosine_similarity

# model = NearestNeighbors(n_neighbors=10, metric='manhattan').fit(X)
model = NearestNeighbors(n_neighbors=10, metric='euclidean').fit(X)
# model = NearestNeighbors(n_neighbors=10, algorithm= 'brute', metric='cosine').fit(X) # используется в статье

# %%
distances, indices = model.kneighbors(X[34].reshape(1, -1))
print(distances)
# Out:
# [[ 0.         10.68260096 10.68260096 12.00311559 12.14852991 12.275956
#   12.34511707 12.62758127 12.86263184 12.9135018 ]]

# %%
indices = indices.flatten()
nearest = y[indices]

# %%
for id in winestyle.iloc[nearest]['id']:
    print(id)
    print(winestyle_upgrade['description'][id] + '\n')
    print(winestyle_filtered['description'][id] + '\n')
# Out:
# 150
# В освежающем аромате вина чувствуются оттенки белого персика и жимолости. Вино демонстрирует свежий, гармоничный вкус с нотами цитрусовых и экзотических фруктов, тонкой кислинкой и стойким послевкусием. Domaine du Petit Clocher, Sauvignon, Val de Loire IGP — изящное полусухое вино, в производстве которого используется виноград сорта Совиньон Блан. Ягоды произрастают на сланцевых почвах долины Луары. Сбор урожая проводится вручную и механически, на винодельне плоды подвергаются краткой мацерации на кожице в последующей ферментацией в стальных резервуарах. Бутилирование вина проводится в конце декабря. Вино станет прекрасным аперитивом, а также рекомендуется подавать к блюдам из рыбы и другим морепродуктам.
#
# свеж освеж кисл изящн легкотел жимол пол пол стал средн цитрус фрукт ягод виноград персик кож сух полусух бел ван
#
# 19382
# Вино обладает изящным букетом с нотками цитрусовых, белых цветов, персика и едва различимыми оттенками луговых трав. Вкус вина "Isla Negra" Sauvignon Blanc-Semillon 2011 освежающий, полусухой и сбалансированный, с оттенками лимона и лайма в послевкусии. "Isla Negra" Sauvignon Blanc-Semillon — белое полусухое вино, которое получают из сортов винограда Совиньон Блан и Семильон. Процесс его производства проходит исключительно в чанах из нержавеющей стали. Это первый удачный опыт виноделов хозяйства по сочетанию двух белых сортов винограда. Isla Negra — это подразделение винодельческого хозяйства Cono Sur, которое было создано в 1995 году и получило свое название в честь прибрежного города в Чили, где были расположены первые виноградники винодельни. Стратегия компании — создавать вино высокого качества по доступной для потребителя цене. Вина, производимые хозяйством, — свежие, приятные и не отягощенные, при этом вкусовая палитра весьма разнообразна, и вино можно подобрать для любого случая и на любой, даже самый изысканный вкус. Ассортимент Isla Negra — это выразительные вина, которые передают наиболее яркие стороны Чили. За последние 10 лет компания достигла значимых достижений. Вина пользуются спросом у покупателей, а высокие рейтинги подтверждают правильно выбранную стратегию.
#
# ярк цитрус свеж освеж полнотел вес изящн изыск пот лимон пол пол пол пол пол пол стал средн цвет цветочн сир лайм сочн сочн виноград персик лич сух сух полусух полусух ржав ча ча трав тим бел бел бел ван лад
#
# 24328
# Вино обладает изящным букетом с нотками цитрусовых, белых цветов, персика и едва различимыми нюансами луговых трав. Вкус Cono Sur Isla Negra Sauvignon Blanc-Semillon 2011 освежающий, полусухой и сбалансированный, с оттенками лимона и лайма в послевкусии. Cono Sur Isla Negra Sauvignon Blanc-Semillon bag in box 2011 — белое полусухое вино, которое получают из сортов винограда Совиньон блан и Семильон. Процесс его производства проходит исключительно в чанах из нержавеющей стали. Это первый удачный опыт виноделов хозяйства по сочетанию двух белых сортов винограда. Isla Negra — это подразделение винодельческого хозяйства Cono Sur, которое было создано в 1995 году и получило свое название в честь прибрежного города в Чили, где были расположены первые виноградники винодельни. Стратегия компании — создавать вино высокого качества по доступной для потребителя цене. Вина, производимые хозяйством, — свежие, приятные и не отягощенные, при этом вкусовая палитра весьма разнообразна, и вино можно подобрать для любого случая и на любой, даже самый изысканный вкус. Ассортимент Isla Negra — это выразительные вина, которые передают наиболее яркие стороны Чили. За последние 10 лет компания достигла значимых достижений. Вина пользуются спросом у покупателей, а высокие рейтинги подтверждают правильно выбранную стратегию.
#
# ярк цитрус свеж освеж полнотел вес изящн изыск пот лимон пол пол пол пол пол пол стал средн цвет цветочн сир лайм сочн сочн виноград персик лич сух сух полусух полусух ржав ча ча трав тим бел бел бел ван лад
#
# 27373
# Кибитц имеет свежий, очаровательный аромат с нотками персика и абрикоса. Вино обладает ярким, приятным вкусом с нюансами ирисок и длительным медово-лимонным послевкусием. Willi Opitz Kiebitz 2008 — белое полусухое вино, название которого переводится как "чибис" — эта птичка обитает в Бургенланде, где и производится вино. Кибитц получают из винограда сортов Пино Гри, Вельшрислинг и Шойребе. После сбора и ферментации, вино выдерживают в стальных емкостях. Производителем вина является Вилли Опиц, который основал винодельню в 1995 году, и не имея опыта, сумел добиться успеха в новой сфере. На сегодняшний день винодельне принадлежат 17 акров виноградников и 7 акров арендованы у других хозяйств. Это семейная компания, в управлении которой принимают участие Вилли Опитц и две его дочери — Мэри и Анджела. Кроме них, на винодельне работают еще 6 сотрудников. Ассортимент винодельни включает в себя 30 вин, изготовленных из 10 сортов винограда. Об успехе предприятия говорят многочисленные награды и высокие оценки вин. К примеру. «WINE SPECTATOR» ежегодно удостаивает вина предприятия высокими оценками, а в 1996 г. специализированный журнал WINE присвоил Опитцу звание «Винодел года».
#
# ярк цитрус свеж ирис лимон мед сот пол пол стал мел долг средн сочн сочн сочн виноград жел абрикос персик фрукт косточк спец сух полусух полусладк ча ча ча ча тим рев ум бел ван ван дер лад
#
# 15251
# Освежающий аромат вина раскрывается оттенками персика, груши, яблока, цитрусовых и жимолости. Вино демонстрирует чистый, мягкий вкус с цитрусов-минеральными акцентами и утонченной кислинкой в гармоничном послевкусии. Karl May, Riesling Classic — органическое полусухое белое вино, созданное из винограда сорта Рислинг, который произрастает на виноградниках Wonnegau. По окончании сбора урожая ягоды отправляются на винодельню, где они подвергаются мягкому прессованию с последующей ферментацией в стальных резервуарах. Непродолжительная выдержка также проводится в чанах из нержавеющей стали. Вино может использоваться как аперитив, а также в сочетании с рыбой, супами, блюдами из грибов.
#
# чист свеж освеж кисл жимол мягк мягк пол пол стал минер гриб долг средн цитрус цитрус ягод виноград персик яблок груш сух полусух полусладк ржав ча ча бел ван дер
#
# 5887
# Гармоничный, изящный аромат вина раскрывается оттенками тропических фруктов, персика, нектарина и трав. Вино интригует мягким, сбалансированным вкусом с фруктово-минеральными оттенками и утонченной кислинкой в послевкусии. Элегантное полусухое вино Pampas del Sur, "Vineyard's Expressions" Torrontes производится из винограда сорта Торронтес, выращенного на аллювиальных почвах в Тупунгато. Собирают урожай вручную в первую неделю марта в небольшие ящики. На винодельне ягоды подвергаются дестеблированию и бережному прессованию. Для сохранения свежего вкуса перед ферментацией кожица ягод замораживается. Ферментация проводится в стальных емкостях при контролируемой температуре 15 °С и длится 20 дней. Перед разливом вино подвергается мембранной фильтрации.
#
# свеж кисл сильноалкогольн изящн элегантн мягк пол стал минер средн сир нектар фрукт фрукт ягод ягод виноград нектарин персик тропическ фрукт кож сух полусух трав стебел ван ван
#
# 16607
# Вино чарует свежим, гармоничным ароматом, сотканным из нот персика, лимона, минералов и полевых цветов. Вкус вина мягкий, элегантный, с цитрусово-минеральными оттенками и пикантной кислинкой в сдержанном послевкусии. Puklavec & Friends, Riesling Premium — утонченное белое полусухое вино, созданное из винограда сорта Рислинг. Ягоды произрастают на виноградниках компании в северо-восточной части Словении. По окончании сбора урожая виноград отправляется на винодельню, где подвергается бережному прессованию с последующей ферментацией в стальных резервуарах со строгим контролем температуры. Вино прекрасно сочетается с креветками, морскими гребешками, лобстерами, лазаньей с морепродуктами, блюдами из телятины.
#
# цитрус свеж кисл пикантн элегантн лимон сот мягк пол пол сдерж стал минер средн цвет цветочн ягод виноград персик сух полусух полусладк ча ча ча рев бел ван дер
#
# 23452
# Элегантный, свежий аромат вина раскрывается оттенками персика, абрикоса и тропических фруктов. Вино демонстрирует чистый, мягкий вкус с фруктово-цитрусовыми оттенками и легкими медовыми нюансами в свежем послевкусии. Echeverria, "Hacienda de Molina" Leyenda Chardonnay — полусухое белое вино из винограда сорта Шардоне, который произрастает на виноградниках компании в Центральной Долине. Сбор урожая проводится в начале марта вручную, ягоды помещают в 18-килограммовые ящики и сразу отправляют на винодельню. На винодельне плоды подвергаются охлаждению до температуры 8 °С с последующим прессованием пневматическим прессом. Ферментация сусла проходит в стальных резервуарах при температуре 13-17 °С и длится 25 дней. Выдерживается вино непродолжительное время в емкостях из нержавеющей стали. Свою историю компания Эчеверрия ведет с 1900 года, с того момента, когда Роберто Эчеверрия разбил в долине Курико свой первый виноградник. Он был настоящим профессионалом в своем деле, поэтому выбрал новые высококачественные клоны Каберне Совиньона, Мерло, Шардоне и Совиньон Блан, и результаты не заставили себя ждать. В течение короткого времени вина Эчеверрия стали известны далеко за пределами Чили, а сегодня их можно найти в лучших ресторанах Европы, Азии и Америки, так как каждое вино создается с особым вниманием и любовью. Немаловажно и то, что для возделывания лозы используются только органические удобрения и минимум инсектицидов, благодаря чему вина Эчеверрия отличаются высокой экологичностью. Сегодня долина Курико является одним из самых престижных винодельческих регионов Чили, ведь благодаря прекрасным почвам, идеальному климату с большим количеством солнечных дней и чистой ледниковой воде Анд здесь создаются исключительные вина высочайшего качества.
#
# чист чист свеж свеж сильноалкогольн слабоалкогольн полнотел вес элегантн легк легкотел мед мягк пол пол стал кор долг средн цитрус фрукт фрукт сочн сочн ягод виноград виноград абрикос персик фрукт косточк лич лич тропическ фрукт сол кол кол сух полусух ржав ча ча ча ум бел ван ван дер
#
# 6098
# Освежающий аромат вина окутывает нотами белых фруктов и цветов. Особую пикантность букету добавляют цитрусовые нюансы. Вкус вина мягкий, округлый, свежий, гармоничный, с оттенками персика, груши, грейпфрута и белых цветов, сбалансированной кислотностью и элегантным, освежающим послевкусием. Connoisseur, "Le Cheval Marin" Colombard-Sauvignon-Gros Manseng — изысканное белое полусухое вино, изготовленное из винограда сортов Коломбар, Совиньон и Гро Мансенг, которые выращиваются на глинисто-известковых почвах в Кот де Гасконь. Название линейки "Connoisseur" переводится с французского как "знаток, ценитель" и предназначена для искушенных винолюбов. Название вина переводится с французского как "морской конек", что призвано напомнить о местных почвах, богатых морскими ископаемыми. Виноград собирают механическим способом ночью, в прохладные часы, чтобы сохранить все ароматы плодов. Винификация протекает в стальных чанах при контролируемой температуре. Вино выдерживается на благородном осадке в течение 3 месяцев.
#
# кислотн свеж свеж освеж освеж кисл пикантн полнотел богат вес элегантн изыск мягк пол стал глин суглинок средн цвет цвет цветочн цветочн сир цитрус грейпфрут фрукт виноград виноград персик бел фрукт груш кол сух полусух сен ча ча рев рев бел бел бел ван ван дер угл лад
#
# 9430
# Аромат вина состоит из нот спелой груши, яблок, оттенков цитрусовых и душистых трав. Вино обладает мягким, свежим, фруктовым вкусом с гармоничной кислотностью, нотами желтых фруктов и нюансами цитрусовых. Белое полусухое столовое вино "Pierre La Grange" Blanc Demi-Sec производится из купажа европейских и французских сортов винограда. Винификация напитка происходит традиционным способом, применяемым для изготовления белых полусухих вин. Ферментация происходит в танкерах из нержавеющей стали при строго контролируемой низкой температуре. После окончания ферментации вино проходит стабилизацию в чанах из нержавеющей стали до самого розлива в бутылки. Les Domaines Montariol Degroote была создана Пьером Дегрот, имеющим репутацию истинного новатора, и семьей Монтариоль (экс-владельцами "Les Domaines Virginie"). Компанию ценят и отмечают как одну из лучших в производстве качественных вин Лангедок-Руссильона. Владельцам принадлежит 540 гектаров виноградников в Лангедок-Руссильоне: Domaine Virginie la Grange, Domaine Bosquet, Domaine Galetis, Domaine des Fontaines, Domaine Rivoire, Domaine Ribaute, Domaine Lalande. Также компания владеет 350 гектарами виноградников в Тунисе (AOC Mornag) и 175 гектарами в Румынии (AOC Dealu Маре). Сильной стороной Пьера Дегрот, наряду с мастерством энолога и страстной преданности земле, являются великолепные знания маркетинга и экспортных рынков, что позволяет ему выгодно отличаться от других виноделов, будучи в состоянии предвидеть эволюцию потребления вина.
#
# кислотн свеж кисл пот мягк пол пол спел стал стал земл роз цитрус цитрус фрукт фрукт виноград виноград жел желт фрукт яблок груш лич кол сух сух полусух полусух сильн ржав ржав ча ча ча ча трав ум бел бел желт лад лад лад лад

# %%
winestyle_upgrade.iloc[nearest]
# Out:
#                                                     name  ... descriptor_count
# id                                                        ...
# 150    Domaine du Petit Clocher, Sauvignon, Val de Lo...  ...               20
# 19382           Isla Negra Sauvignon Blanc-Semillon 2011  ...               41
# 24328  Isla Negra Sauvignon Blanc-Semillon bag in box...  ...               41
# 27373                           Willi Opitz Kiebitz 2008  ...               38
# 15251                   Karl May, Riesling Classic, 2017  ...               30
# 5887   Pampas del Sur, "Vineyard's Expressions" Torro...  ...               28
# 16607         Puklavec & Friends, Riesling Premium, 2018  ...               29
# 23452  Echeverria, "Hacienda de Molina" Leyenda Chard...  ...               49
# 6098   Connoisseur, "Le Cheval Marin" Colombard-Sauvi...  ...               48
# 9430                   "Pierre La Grange" Blanc Demi-Sec  ...               45
#
# [10 rows x 17 columns]

# %% [markdown]
# ## Step 6. Grape analysis

# %% [markdown]
# Посчитала и посмотрела какие сорта винограда у нас вообще есть

# %%
dict_grape = Counter(winestyle_upgrade['grape'])


grapes = [key.split(', ') for key in dict_grape.keys() if str(key) != 'nan']
grapes = sum(grapes,[])
grapes = Counter(grapes)
print('У нас есть', len(grapes), 'сорт(ов) винограда. Как дальше жить?')
print(grapes)

most_common = []
for item in grapes.items():
    if item[1] > 50:
        most_common.append(item[0])
print(len(most_common))
most_common
# Out:
# У нас есть 704 сорт(ов) винограда. Как дальше жить?
# Counter({'Каберне Совиньон': 559, 'Шардоне': 476, 'Мерло': 459, 'Сира': 413, 'Совиньон Блан': 319, 'Гренаш/Гарнача': 300, 'Санджовезе': 198, 'Рислинг': 188, 'Каберне Фран': 172, 'Пино Нуар': 172, 'Шираз': 151, 'Пти Вердо': 144, 'Красные сорта винограда': 142, 'Турига Насьональ': 132, 'Вионье': 132, 'Темпранильо': 126, 'Мальбек': 124, 'Кариньяно': 122, 'Мурведр': 108, 'Алиготе': 106, 'Пино Блан': 105, 'Белые сорта винограда': 99, 'Сенсо': 98, 'Мускат': 96, 'Мальвазия': 96, 'Другие сорта': 95, 'Корвина': 93, 'Тинта Рориз': 88, 'Гренаш Блан': 87, 'Треббьяно': 84, 'Ркацители': 82, 'Саперави': 82, 'Турига Франсеса/Турига Франка': 80, 'Аликанте': 80, 'Макабео': 74, 'Семильон': 73, 'Шенен Блан': 73, 'Аринту': 71, 'Рондинелла': 70, 'Карменере': 64, 'Гарганега': 63, 'Руссан': 62, 'Верментино': 61, 'Уни Блан': 58, 'Кларет': 56, 'Барбера': 55, 'Траминер': 55, 'Пино Бьянко': 55, 'Канайоло': 53, 'Пино Гриджио': 52, 'Коломбар': 51, 'Пино Гри': 48, 'Гевюрцтраминер': 47, 'Тинта Баррока': 42, 'Корвиноне': 40, 'Фернау Пиреш': 40, 'Марсан': 40, 'Каштелау': 40, 'Монастрель': 38, 'Монтепульчано': 38, 'Виозиньо': 38, 'Гаме': 38, 'Глера (Просекко)': 38, 'Роль': 36, 'Молинара': 36, 'Виура': 36, 'Треббьяно Тоскано': 36, 'Мальвазия Фина': 35, 'Таннат': 35, 'Зинфандель': 35, 'Грекетто': 35, "Неро д'Авола": 34, 'Москато Бьянко': 34, 'Сузао': 34, 'Пти Шираз': 34, 'Пино Неро': 34, 'Неббиоло': 33, 'Рабигато': 33, 'Вердехо': 32, 'Кокур': 32, 'Грюнер Вельтлинер': 32, 'Айрен': 32, 'Катарратто': 32, 'Негроамаро': 31, 'Тинта Као': 31, 'Москатель': 31, 'Пинотаж': 30, 'Гувейо': 30, 'Мускат Оттонель': 30, 'Арагонеш': 30, 'Пти Сира': 30, 'Чарелло': 30, 'Грасиано': 29, 'Тинта Амарела': 29, 'Кортезе': 29, 'Мальвазия Нера': 29, 'Кроатина': 29, 'Колорино': 28, 'Мюллер-Тургау': 28, 'Токай Фриулано': 28, 'Бурбуленк': 27, 'Примитиво': 25, 'Бобаль': 25, 'Верделло': 24, 'Чильеджоло': 24, 'Парельяда': 24, 'Лоурейру': 23, 'Серсиаль': 23, 'Гарнача Тинторерра': 23, 'Цвайгельт': 23, 'Нерелло Маскалезе': 22, 'Оселета': 22, 'Мальвазия Бьянка': 22, 'Бастардо': 21, 'Мюскадель': 21, 'Мускат Александрийский': 21, 'Вельшрислинг': 21, 'Фурминт': 21, 'Тринкадейра': 21, 'Бонарда': 20, 'Греканико': 20, 'Пино Фран': 20, 'Альбариньо': 19, 'Грилло': 19, 'Сильванер': 19, 'Кодега': 18, 'Инзолия': 18, 'Карриканте': 18, 'Пти Мансенг': 18, 'Бастардо Магарачский': 17, 'Педро Хименес': 17, 'Мускатные сорта винограда': 17, 'Мцване': 17, 'Гро Мансенг': 17, 'Гарнача бланка': 17, 'Вайссбургундер': 17, 'Бага': 17, 'Альбильо': 16, 'Масуэло': 16, 'Марселан': 16, 'Торронтес': 16, 'Каберне Совиньон и Каберне Фран': 16, 'Фриулано': 16, 'Ламбруско Саламино': 16, 'Фиано': 15, 'Альянико': 15, 'Греко': 15, 'Харшлевелю': 15, 'Рефоско': 15, 'Анчеллотта': 15, 'Мускат Гамбургский': 15, 'Мускат янтарный': 15, 'Риболла Джалла': 15, 'Проканико': 15, 'Оксеруа Блан': 15, 'Менсия': 14, 'Терольдего': 14, 'Одесский Черный': 14, 'Бикал': 14, 'Нойбургер': 14, 'Арени': 13, 'Каберне Совиньон и Мерло': 13, 'Цимлянский черный': 13, 'Мальвазия дель Лацио': 13, 'Блауфранкиш': 13, 'Санджовезе Гроссо (Брунелло)': 13, 'Дольчетто': 13, 'Каннонау': 13, 'Кунуаз': 13, 'Рабозо': 13, 'Бианка': 13, 'Тибурен': 12, 'Мальвазия ди Кандия': 12, 'Самсо': 12, 'Пино Менье': 12, 'Лагрейн': 12, 'Шойребе': 12, 'Жаен': 12, 'Гренаш Гри': 12, 'Маммоло': 12, 'Мерсегера': 11, 'Трейщадура': 11, 'Гролло': 11, 'Пикпуль': 11, 'Ассиртико': 11, 'Фоль Бланш': 11, 'Фалангина': 11, 'Энкрузаду': 11, 'Фреиза': 11, 'Ламбруско Граспаросса': 11, 'Мускат Розовый': 10, 'Александроули': 10, 'Пруньоло': 10, 'Тинто Фино': 10, 'Марцемино': 10, 'Вранац': 10, 'Кефесия': 10, 'Руфете': 10, 'Тражадура': 10, 'Авессу': 10, 'Неграра': 10, 'Антау Важ': 10, 'Инкрочио Манзони': 10, 'Цицка': 10, 'Вердиккио': 10, 'Матаро': 10, 'Ламбруско Маэстри': 10, 'Азаль Бранко': 9, 'Цоликаури': 9, 'Кангун': 9, 'Эшпадейру': 9, "Монтепульчано д'Абруццо": 9, 'Тинта Франческа': 9, 'Красностоп': 9, 'Каладок': 9, 'Сибирьковый': 9, 'Мускардэн': 9, 'Ламбруско': 9, 'Альфрокейро': 9, 'Воскеат': 9, 'Руби Каберне': ...
# 51
# ['Мерло',
#  'Темпранильо',
#  'Гренаш/Гарнача',
#  'Санджовезе',
#  'Сира',
#  'Кариньяно',
#  'Каберне Совиньон',
#  'Каберне Фран',
#  'Совиньон Блан',
#  'Мускат',
#  'Верментино',
#  'Рислинг',
#  'Пти Вердо',
#  'Ркацители',
#  'Пино Нуар',
#  'Мальбек',
#  'Сенсо',
#  'Семильон',
#  'Аринту',
#  'Шираз',
#  'Турига Насьональ',
#  'Турига Франсеса/Турига Франка',
#  'Тинта Рориз',
#  'Красные сорта винограда',
#  'Корвина',
#  'Пино Гриджио',
#  'Белые сорта винограда',
#  'Саперави',
#  'Рондинелла',
#  'Барбера',
#  'Алиготе',
#  'Гренаш Блан',
#  'Мальвазия',
#  'Шардоне',
#  'Гарганега',
#  'Вионье',
#  'Уни Блан',
#  'Коломбар',
#  'Пино Блан',
#  'Карменере',
#  'Аликанте',
#  'Мурведр',
#  'Канайоло',
#  'Траминер',
#  'Треббьяно',
#  'Шенен Блан',
#  'Макабео',
#  'Другие сорта',
#  'Руссан',
#  'Кларет',
#  'Пино Бьянко']

# %%
def subset_wine_vectors(list_of_varieties):
    wine_variety_vectors = []
    for v in list_of_varieties:
        one_var_only = winestyle_upgrade.loc[winestyle_upgrade['grape'] == v]
        review_arrays = one_var_only['review_vector'].apply(lambda x: x[0])
        average_variety_vec = np.average(review_arrays)
        wine_variety_vector = [v, average_variety_vec]
        wine_variety_vectors.append(wine_variety_vector)
    return wine_variety_vectors

def pca_wine_variety(list_of_varieties):
    wine_var_vectors = subset_wine_vectors(list_of_varieties)
    pca = PCA(n_components=2)
    pca.fit([w[1] for w in wine_var_vectors])  
    pca_dataset = pca.fit_transform([w[1] for w in wine_var_vectors])
    pca_dataframe = pd.DataFrame(pca_dataset, columns=['pca_1', 'pca_2'])
    pca_dataframe.index = [w[0] for w in wine_var_vectors]
    # print(pca_dataframe)
    return pca_dataframe

# %%
from sklearn.decomposition import PCA
pca_r_dataframe = pca_wine_variety(most_common)
plt.figure(figsize=(20, 20))
plt.scatter(x=pca_r_dataframe['pca_1'], y=pca_r_dataframe['pca_2'])
for i, txt in enumerate(pca_r_dataframe.index):
    plt.annotate(txt, (list(pca_r_dataframe['pca_1'])[i]+0.2, list(pca_r_dataframe['pca_2'])[i]-0.1), fontsize=12)

plt.xlabel('PCA Factor 1')
plt.ylabel('PCA Factor 2')
plt.title('Average Wine Embeddings for Most Common Red Wines', fontsize=16)
plt.show()
